# %% [markdown]
# # String

# %% [markdown]
# A string is a sequence of characters.
# In Python, strings are made of Unicode characters,
#
# meaning they can represent letters, numbers, symbols, and emojis from all languages.

# %% [markdown]
# ## 1. Create

# %%
a="Hello"

# %%
a
# Out:
# 'Hello'

# %%
b='Hello'

# %%
b
# Out:
# 'Hello'

# %%
'It's raining outside'
# Out:
#   Cell In[5], line 1
#     'It's raining outside'
#                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"It's raining outside"
# Out:
# "It's raining outside"

# %%
# multi line string
d = '''This is
a multiline 
string'''
print(d)
# Out:
# This is
# a multiline
# string

# %% [markdown]
# ## 2. Accessing String

# %% [markdown]
# **Accessing substring from a string**

# %%
# Concept of indexing 
c='Hello'
print(c)
# Out:
# Hello

# %% [markdown]
# Indexing Type
#  1. positive
#  2. Negative

# %%
print(c[0])
# Out:
# H

# %%
print(c[1])
# Out:
# e

# %%
print(c[-1])
# Out:
# o

# %%
print(c[-2])
# Out:
# l

# %%
#slicing 
print(c[0:5])
# Out:
# Hello

# %%
print(c[1:3])
# Out:
# el

# %%
print(c[2:])
# Out:
# llo

# %%
print(c[:4])
# Out:
# Hell

# %%
print(c[2:6:2])
# Out:
# lo

# %%
print(c[0:8:3])
# Out:
# Hl

# %%
d='bangladesh'

# %%
print(d[0:10:3])
# Out:
# bgdh

# %%
print(c[:-1])
# Out:
# Hell

# %%
print(c[:4])
# Out:
# Hell

# %%
print(c[::-1])
# Out:
# olleH

# %% [markdown]
# ## 3. Add Char

# %%
str1='Hello'
str2='World'
another_str=str1+' '+str2

# %%
another_str
# Out:
# 'Hello World'

# %%
new_str=another_str+", How are you"

# %%
new_str
# Out:
# 'Hello World, How are you'

# %% [markdown]
# ## 4. Edit & 5.Delete

# %%
c = "Hello"
print(c)

# %%
c[0] = 'X'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 c[0] = 'X'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Strings are a Immutable Data Types. We can not edit strings afters it assign. We can completely reassign string but can not edit existing

# %%
c = "World"
print(c)
# Out:
# World

# %%
c[5] = "X"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 c[5] = "X"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# c

# %%
del c

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
c='hello'

# %%
c
# Out:
# 'hello'

# %%
del c[:3:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 del c[:3:2]
#
# TypeError: 'str' object does not support item deletion

# %%
del c[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 del c[0]
#
# TypeError: 'str' object doesn't support item deletion

# %% [markdown]
# ## 6. Ops on Strings
#
# Arithmetic: Concatenation (+), Repetition (*)
#
# Relational: Equality (==), Inequality (!=), Comparison (<, >, <=, >=)
#
# Logical: and, or, not
#
# Loops: for loop, while loop
#
# Membership: in, not in

# %%
# Arithmetic

'Hello' + '-'+ 'World'
# Out:
# 'Hello-World'

# %%
print('*'*50)
# Out:
# **************************************************

# %%
print('Hello'*4)
# Out:
# HelloHelloHelloHello

# %%
# Relational
'Hello'=='World'
# Out:
# False

# %%
'Hello'!='World'
# Out:
# True

# %%
'Mumbai'>'Pune' # Lexiographically
# Out:
# False

# %% [markdown]
# Lexicographically means dictionary order — i.e., how words or strings are arranged alphabetically, character by character, based on their Unicode (or ASCII) values.

# %%
'Dhaka'>'Barisal'
# Out:
# True

# %%
'Dhaka'>'dhaka'
# Out:
# False

# %%
# Logical

# %%
'Hello' and 'World'
# Out:
# 'World'

# %%
'' and 'Hello'
# Out:
# ''

# %%
'' or 'World'
# Out:
# 'World'

# %%
not "Hello"
# Out:
# False

# %%
print(not 'Hello')
# Out:
# False

# %%
not ''
# Out:
# True

# %%
# Loops on string
c='Hello World'
for i in c:
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for i in c[2:7]:
    print(i)
# Out:
# l
# l
# o
#
# W

# %%
for i in c[2:7:2]:
    print(i)
# Out:
# l
# o
# W

# %%
for i in c[::-1]:
    print(i)
# Out:
# d
# l
# r
# o
# W
#
# o
# l
# l
# e
# H

# %%
# membership
'h' in c
# Out:
# False

# %%
'H' in c
# Out:
# True

# %%
'World' in c
# Out:
# True

# %%
'World' not in c
# Out:
# False

# %% [markdown]
# ## 7.String Functions

# %% [markdown]
# ###  Common String Function

# %% [markdown]
# - len()
# - max()
# - min()
# - sorted()

# %%
c='bangladesh'

# %%
len(c)
# Out:
# 10

# %%
min(c)
# Out:
# 'a'

# %%
max(c)
# Out:
# 's'

# %%
sorted(c)
# Out:
# ['a', 'a', 'b', 'd', 'e', 'g', 'h', 'l', 'n', 's']

# %%
sorted(c, reverse=True)
# Out:
# ['s', 'n', 'l', 'h', 'g', 'e', 'd', 'b', 'a', 'a']

# %% [markdown]
# ### 1. Capitalize/Title/Upper/Lower/Swapcase

# %%
c.capitalize()
# Out:
# 'Bangladesh'

# %%
'it is raining'.title()
# Out:
# 'It Is Raining'

# %%
c.upper()
# Out:
# 'BANGLADESH'

# %%
c.upper().lower()
# Out:
# 'bangladesh'

# %%
d='BanGLAdesh'

# %%
d.swapcase()
# Out:
# 'bANglaDESH'

# %% [markdown]
# ### 2. count

# %%
'It is raining'.count('I')
# Out:
# 1

# %%
'It is raining'.count('i')
# Out:
# 3

# %%
'It is raining'.count('is')
# Out:
# 1

# %% [markdown]
# ### 3. Find/Index

# %%
'I am a muslim'.find('a')
# Out:
# 2

# %%
'I am a muslim'.find('I')
# Out:
# 0

# %%
'I am a muslim'.find('x')
# Out:
# -1

# %%
'I am a muslim'.index('a')
# Out:
# 2

# %%
'I am a muslim'.index('muslim')
# Out:
# 7

# %%
'I am a muslim'.index('x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 'I am a muslim'.index('x')
#
# ValueError: substring not found

# %% [markdown]
# difference between find and index is, if u use find to search somethis which is not present in string then it will give result -1 and if we use index it will through an error message

# %% [markdown]
# ### 4. endswith/startswith

# %%
'I am a muslim'.endswith('muslim')
# Out:
# True

# %%
'I am a muslim'.startswith('I')
# Out:
# True

# %%
'I am a muslim'.endswith('muslims')
# Out:
# False

# %% [markdown]
# ### 5. format

# %%
"Hello, My name is {} and i am {} years old".format("Abdur",39)
# Out:
# 'Hello, My name is Abdur and i am 39 years old'

# %%
"Hello, My name is {1} and i am {0} years old".format("Abdur",39)
# Out:
# 'Hello, My name is 39 and i am Abdur years old'

# %%
"Hello, My name is {name} and i am {age} years old".format(name="Abdur",age=39)
# Out:
# 'Hello, My name is Abdur and i am 39 years old'

# %%
"Hello, My name is {name} and i am {weight} years old".format(name="Abdur",age=39,weight=70)
# Out:
# 'Hello, My name is Abdur and i am 70 years old'

# %% [markdown]
# ### 6. isalnum/isalpha/isdecimal/isdigit/isidentifier

# %%
"FLAT20".isalnum()
# Out:
# True

# %%
"FLAT20&".isalnum()
# Out:
# False

# %%
"Flat".isalpha()
# Out:
# True

# %%
"flat20".isalpha()
# Out:
# False

# %%
"20".isdigit()
# Out:
# True

# %%
"20a".isdigit()
# Out:
# False

# %%
"hello world".isidentifier()
# Out:
# False

# %%
"hello_world".isidentifier()
# Out:
# True

# %% [markdown]
# ###  7.split

# %%
"Who is the PM of Bangladesh".split()
# Out:
# ['Who', 'is', 'the', 'PM', 'of', 'Bangladesh']

# %%
"Who is the PM of Bangladesh".split("PM")
# Out:
# ['Who is the ', ' of Bangladesh']

# %% [markdown]
# ### 8. join

# %%
" ".join(['Who', 'is', 'the', 'PM', 'of', 'Bangladesh'])
# Out:
# 'Who is the PM of Bangladesh'

# %%
"-".join(['Who', 'is', 'the', 'PM', 'of', 'Bangladesh'])
# Out:
# 'Who-is-the-PM-of-Bangladesh'

# %% [markdown]
# ### 9. replace

# %%
"Hello My name is DON".replace("DON","Abdur")
# Out:
# 'Hello My name is Abdur'

# %% [markdown]
# ### 10. strip

# %%
name= "     Abdur      "

# %%
name.strip()
# Out:
# 'Abdur'
