# %% [markdown]
# ## List

# %%
# empty list
L=[]
L
# Out:
# []

# %%
# homogenous list(same data type)
L1=[1,2,4,6]
L1
# Out:
# [1, 2, 4, 6]

# %%
# heterogenous list
L2=[1,2, True, 5+4j]

# %%
L2
# Out:
# [1, 2, True, (5+4j)]

# %%
#multi dimensional list
# 2D
L3=[1,2,3,[4,5]]

# %%
L3
# Out:
# [1, 2, 3, [4, 5]]

# %%
#3D
L4= [[[1,2],[3,4]],[[5,6],[7,8]]]
L4
# Out:
# [[[1, 2], [3, 4]], [[5, 6], [7, 8]]]

# %%
L5=['Bangladesh']

# %%
L5
# Out:
# ['Bangladesh']

# %%
L6=[]

# %%
L6
# Out:
# []

# %%
L1[0]
# Out:
# 1

# %%
L1[2]
# Out:
# 4

# %%
L1[-1]
# Out:
# 6

# %%
L3
# Out:
# [1, 2, 3, [4, 5]]

# %%
L3[-1]
# Out:
# [4, 5]

# %%
x=L3[-1]

# %%
x
# Out:
# [4, 5]

# %%
x[0]
# Out:
# 4

# %%
x[1]
# Out:
# 5

# %%
 L3[-1][0]
# Out:
# 4

# %%
L3[-1][1]
# Out:
# 5

# %%
L4
# Out:
# [[[1, 2], [3, 4]], [[5, 6], [7, 8]]]

# %%
L4[1][1][0]
# Out:
# 7

# %%
L4[0][1][1]
# Out:
# 4

# %% [markdown]
# ### adding

# %%
#append 
L=[100,200,400,600]

# %%
L.append(800)

# %%
L
# Out:
# [100, 200, 400, 600, 800]

# %%
L.append("Hello")

# %%
L
# Out:
# [100, 200, 400, 600, 800, 'Hello']

# %%
#extend
L.extend([900,700,"Abdur"])

# %%
L
# Out:
# [100, 200, 400, 600, 800, 'Hello', 900, 700, 'Abdur']

# %%
#append always add one item
L.append([100,200])

# %%
L
# Out:
# [100, 200, 400, 600, 800, 'Hello', 900, 700, 'Abdur', [100, 200]]

# %% [markdown]
# append will always try to append one item and extend will always try to append multiple items

# %%
L.extend("goa")

# %%
L
# Out:
# [100,
#  200,
#  400,
#  600,
#  800,
#  'Hello',
#  900,
#  700,
#  'Abdur',
#  [100, 200],
#  'g',
#  'o',
#  'a']

# %%
L.insert(1,"world")

# %%
L
# Out:
# [100,
#  'world',
#  200,
#  400,
#  600,
#  800,
#  'Hello',
#  900,
#  700,
#  'Abdur',
#  [100, 200],
#  'g',
#  'o',
#  'a']

# %% [markdown]
# ### Deleting

# %% [markdown]
# - delete
# - del
# - remove
# - pop
# - clear

# %%
L2
# Out:
# [1, 2, True, (5+4j)]

# %%
L2
# Out:
# [1, 2, True, (5+4j)]

# %%
L
# Out:
# [100,
#  'world',
#  200,
#  400,
#  600,
#  800,
#  'Hello',
#  900,
#  700,
#  'Abdur',
#  [100, 200],
#  'g',
#  'o',
#  'a']

# %%
del L[0]

# %%
L
# Out:
# ['world',
#  200,
#  400,
#  600,
#  800,
#  'Hello',
#  900,
#  700,
#  'Abdur',
#  [100, 200],
#  'g',
#  'o',
#  'a']

# %%
del L[-4]

# %%
L
# Out:
# ['world', 200, 400, 600, 800, 'Hello', 900, 700, 'Abdur', 'g', 'o', 'a']

# %%
del L[-3:]

# %%
L
# Out:
# ['world', 200, 400, 600, 800, 'Hello', 900, 700, 'Abdur']

# %%
L.remove("Hello")

# %%
L
# Out:
# ['world', 200, 400, 600, 800, 900, 700, 'Abdur']

# %%
#pop delete last items
L.pop()
# Out:
# 900

# %%
L.pop()
# Out:
# 700

# %%
L
# Out:
# ['world', 200, 400, 600, 800, 900]

# %%
#clear makes a list empty
L.clear()

# %%
L
# Out:
# []

# %%
L=[1,2,3]

# %%
L1=[4,5,6]

# %%
#new List upon concatenation
L+L1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
L
# Out:
# [1, 2, 3]

# %%
L1
# Out:
# [4, 5, 6]

# %%
L3=[1,2,3,[4,5]]

# %%
for i in L3:
    print(i)
# Out:
# 1
# 2
# 3
# [4, 5]

# %%
4 in L3
# Out:
# False

# %%
[4,5] in L3
# Out:
# True

# %% [markdown]
# ### functions

# %%
L
# Out:
# [1, 2, 3]

# %%
len(L)
# Out:
# 3

# %%
min(L)
# Out:
# 1

# %%
max(L)
# Out:
# 3

# %%
sorted(L)
# Out:
# [1, 2, 3]

# %%
# not permanent
sorted(L,reverse=True)
# Out:
# [3, 2, 1]

# %%
L
# Out:
# [1, 2, 3]

# %%
# sort is permanent
L.sort()
L
# Out:
# [1, 2, 3]

# %%
L.sort(reverse=True)

# %%
L
# Out:
# [3, 2, 1]

# %%
L
# Out:
# [3, 2, 1]

# %%
L.index(3)
# Out:
# 0

# %%
L.index(1)
# Out:
# 2
